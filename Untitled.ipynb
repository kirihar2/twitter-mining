# %%
from training_data_pre_processing import TrainingData

# %%
training_class = TrainingData()
# Out:
# 2980-INFO-Logging started

# %%
training_data,testing_data = training_class.retrieve_train_test_data('training-data.csv',test_data_size=1000,training_data_size=10000)
# Out:
# 2980-INFO-Created training data of size 10000 and test data of size 1000

# %%
print(len(training_data), len(testing_data) )
# Out:
# 10000 1000

# %%
import pandas as pd

# %%
test_data_frame=pd.DataFrame(testing_data)
print(test_data_frame)
training_data_frame = pd.DataFrame(training_data)
# Out:
#      0                                                  1
# 0    0  [think, theres, problem, area, go, slow, anyth...
# 1    0                                   [go, dying, try]
# 2    0                                   [go, dying, try]
# 3    0           [talking, cant, design, juice, personal]
# 4    0                                       [rainy, day]
# 5    0           [completely, cute, picture, format, big]
# 6    0                          [greatly, public, strike]
# 7    0         [doesnt, single, pair, spring, pants, fit]
# 8    0                                 [tired, dont, god]
# 9    0      [wishing, sun, would, come, going, one, days]
# 10   0                    [spring, finished, going, back]
# 11   0                                            [today]
# 12   0           [opening, bank, mascot, bank, lose, job]
# 13   0  [outside, forecast, say, rain, al, day, crapy,...
# 14   0       [ben, since, early, hour, laying, bed, back]
# 15   0  [could, one, tip, future, would, read, mary, o...
# 16   0                                  [maybe, fun, sun]
# 17   0               [enjoying, cup, captain, c, already]
# 18   0              [at_user, sory, hear, hope, get, son]
# 19   0                    [didnt, know, didnt, quit, fit]
# 20   0    [at_user, want, outside, working, garden, sick]
# 21   0  [oh, crap, came, back, walk, computer, hung, b...
# 22   0                          [hate, dont, let, delete]
# 23   0                                 [tired, impatient]
# 24   0                            [morning, could, slept]
# 25   0                   [at_user, sory, hear, least, us]
# 26   0                                   [broke, vibrate]
# 27   0  [race, god, ran, last, time, didnt, se, at_use...
# 28   0         [at_user, got, home, didnt, want, nothing]
# 29   0                                    [at_user, know]
# ..  ..                                                ...
# 970  0                             [last, picture, erase]
# 971  0                          [ugh, learn, save, money]
# 972  0                                          [reading]
# 973  0              [sick, going, north, star, today, bo]
# 974  0                                   [at_user, watch]
# 975  0                                  [love, wife, son]
# 976  0               [at_user, infected, worm, big, time]
# 977  0                            [save, get, new, touch]
# 978  0              [at_user, going, check, snow, taking]
# 979  0           [at_user, yeah, think, working, tonight]
# 980  0             [at_user, yes, girl, spending, inside]
# 981  0                             [dead, bad, way, damn]
# 982  0                    [at_user, phone, available, us]
# 983  0  [alive, alive, several, repeated, tho, like, p...
# 984  0                     [da, last, da, residence, sad]
# 985  0                           [stuck, hospital, least]
# 986  0              [at_user, hey, please, reply, people]
# 987  0                                       [damn, back]
# 988  0                                         [al, play]
# 989  0                           [doesnt, want, go, work]
# 990  0  [at_user, like, kind, thing, stay, around, hou...
# 991  0  [working, region, gymnastics, met, everyone, e...
# 992  0                       [camera, take, family, trip]
# 993  0  [at_user, hi, nick, hope, want, talk, whit, li...
# 994  0            [work, wishing, could, ran, g, instead]
# 995  0                    [never, drinking, sore, throat]
# 996  0                               [living, next, year]
# 997  0                                [at_user, aw, help]
# 998  0                                       [play, rain]
# 999  0                                  [god, rainy, day]
#
# [1000 rows x 2 columns]

# %%
print(test_data_frame[1].tolist())
# Out:
# [['think', 'theres', 'problem', 'area', 'go', 'slow', 'anything', 'yesterday', 'today'], ['go', 'dying', 'try'], ['go', 'dying', 'try'], ['talking', 'cant', 'design', 'juice', 'personal'], ['rainy', 'day'], ['completely', 'cute', 'picture', 'format', 'big'], ['greatly', 'public', 'strike'], ['doesnt', 'single', 'pair', 'spring', 'pants', 'fit'], ['tired', 'dont', 'god'], ['wishing', 'sun', 'would', 'come', 'going', 'one', 'days'], ['spring', 'finished', 'going', 'back'], ['today'], ['opening', 'bank', 'mascot', 'bank', 'lose', 'job'], ['outside', 'forecast', 'say', 'rain', 'al', 'day', 'crapy', 'start'], ['ben', 'since', 'early', 'hour', 'laying', 'bed', 'back'], ['could', 'one', 'tip', 'future', 'would', 'read', 'mary', 'ouch'], ['maybe', 'fun', 'sun'], ['enjoying', 'cup', 'captain', 'c', 'already'], ['at_user', 'sory', 'hear', 'hope', 'get', 'son'], ['didnt', 'know', 'didnt', 'quit', 'fit'], ['at_user', 'want', 'outside', 'working', 'garden', 'sick'], ['oh', 'crap', 'came', 'back', 'walk', 'computer', 'hung', 'black', 'graphics', 'even', 'post'], ['hate', 'dont', 'let', 'delete'], ['tired', 'impatient'], ['morning', 'could', 'slept'], ['at_user', 'sory', 'hear', 'least', 'us'], ['broke', 'vibrate'], ['race', 'god', 'ran', 'last', 'time', 'didnt', 'se', 'at_user', 'at_user', 'though'], ['at_user', 'got', 'home', 'didnt', 'want', 'nothing'], ['at_user', 'know'], ['work', 'blah'], ['at_user', 'wish', 'participate'], ['site', 'believe', 'server', 'unavailable', 'whats'], [''], ['hate', 'homework', 'oh', 'ya', 'today', 'want'], ['last', 'night'], ['another', 'gorgeous', 'day', 'dry', 'four', 'rain', 'days', 'coming', 'wildfire'], ['at_user', 'love', 'gift', 'must', 'se', 'son'], ['right'], ['got', 'way', 'road', 'closed', 'due', 'driving', 'hungry'], ['couch', 'working'], ['work', 'back', 'hope'], ['figure', 'phone'], ['stuck', 'without', 'ride', 'taking', 'bus', 'home', 'work', 'without'], ['at_user', 'alas', 'setup'], ['at_user', 'got', 'seven', 'yes', 'man', 'wasnt', 'red', 'box', 'went'], ['ugh', 'hate', 'working', 'never', 'fels', 'like'], ['goes', 'great', 'day', 'rip'], ['motel', 'blow', 'either'], ['almost', 'done', 'back', 'work', 'son'], ['til', 'son'], ['get', 'se', 'sing', 'els', 'gig', 'dog', 'tonight'], ['home', 'writing', 'due', 'ago', 'weather', 'god', 'time'], ['se', 'sing', 'last', 'night', 'bring', 'park'], ['starting', 'far', 'many', 'moving', 'furniture', 'furniture'], ['back', 'painting'], ['at_user', 'walk', 'last', 'night', 'like'], ['snow', 'mounted', 'couple', 'overnight', 'hope', 'dont', 'lose'], ['at_user', 'dont', 'confirmation', 'could', 'give', 'already'], ['at_user', 'cop'], ['at_user', 'old', 'great'], ['headed', 'rain', 'rain', 'dance', 'backwards', 'make', 'stop'], ['get', 'hope', 'god', 'store', 'alcoholic'], ['ridiculous', 'blaming'], ['everyone', 'talking', 'want', 'go'], ['yawn', 'headache', 'depart', 'chai', 'wrap', 'head', 'around', 'day'], ['listening', 'belong', 'together'], ['at_user', 'sory', 'work'], ['cold', 'outside'], ['at_user', 'something', 'friendly', 'banter', 'u', 'right'], ['turned'], ['alright', 'spent', 'al', 'yesterday', 'far', 'away', 'computer', 'today', 'today', 'come', 'back', 'al'], ['at_user', 'la', 'least', 'at_user'], ['woke', 'tired'], ['going', 'super', 'already', 'though'], ['anyone', 'cant', 'reason', 'maybe', 'try'], ['morning', 'fam', 'next', 'road', 'march', 'wut'], ['bye', 'bye', 'plane', 'anyone', 'want', 'private', 'jet', 'c', 'one'], ['at_user', 'link', 'today', 'show', 'doesnt', 'work', 'think', 'u', 'take'], ['eating', 'last', 'breakfast', 'boat'], ['sun', 'go'], ['cant', 'se', 'number'], ['at_user', 'think', 'shy', 'p', 'know', 'exactly', 'wrote', 'much', 'mistake'], ['at_user'], ['like', 'mad', 'hate', 'duty'], ['want', 'today', 'think', 'busy', 'get'], ['broken', 'shift', 'key'], ['at_user', 'instead', 'giving', 'charity', 'give', 'much', 'goes'], ['nothing', 'yet'], ['at_user', 'song', 'cant', 'se', 'link'], ['got', 'finish', 'work', 'exam'], ['at_ ...

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
y_pred = gnb.fit(training_data_frame[0].tolist(), training_data_frame[1].tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ad4b9849f7c6> in <module>()
#       1 gnb = GaussianNB()
# ----> 2 y_pred = gnb.fit(training_data_frame[0].tolist(), training_data_frame[1].tolist())
#
# /anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     181             Returns self.
#     182         """
# --> 183         X, y = check_X_y(X, y)
#     184         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     185                                  sample_weight=sample_weight)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['0' '0' '0' ... '0' '0' '0'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
